# %% [markdown]
# 1)Both datasets contain information about students and their gaming sessions The first dataset contains the columns
# -Experience is a categorical variable of the experience of a player (Pro, Veteran, Amateur). A potential issue is that there is no clear cut off for each experience level
#
# -Subscribe is a categorical or boolean value which shows if they are subscribed or not (True or False). An issue could be if there are missing values
#
# -HashedEmail is a quantitative variable which describes the email of the user
#
# -Played hours is a quantitative variable showing how many hours a player has played. An issue could be missing data causing inaccurate data.
#
# -Users name is a quantitative variable which will not be used in the analysis
#
# -Gender categorical variable telling us the users Gender
#
# -Age is a quantitative variable but could be skewed if there is missing data
#
# -Start time is a quantitative variable describing when the player starts playing
#
# -End time is a quantitative variable describing when the player stops playing

# %% [markdown]
# 2)  We would like to know which "kinds" of players are most likely to contribute a large amount of data so that we can target those players in our recruiting efforts.
#
#    The response variable will be the total duration of hours played along with the number of sessions that each user did. The explanatory variable will be the player type (A catagorical variable describing the players experience level).
#
# To work with the data I will first arrange my response variable in decending order to find which player type is has played the most and had the most sessions. I will then group my data by the player type that is most likely to have gathered the most data

# %%
import pandas as pd
import altair as alt
players = pd.read_csv("data/players.csv")  #This is Tidy
sessions = pd.read_csv("data/sessions.csv")

sessions_tidy = pd.melt(sessions, id_vars=['hashedEmail'], 
                        value_vars=['start_time', 'end_time', 'original_start_time', 'original_end_time'],
                  var_name='time_type', value_name='value')
sessions_tidy

players
# Out:
#     experience  subscribe                                        hashedEmail  \
# 0          Pro       True  f6daba428a5e19a3d47574858c13550499be23603422e6...
# 1      Veteran       True  f3c813577c458ba0dfef80996f8f32c93b6e8af1fa9397...
# 2      Veteran      False  b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3...
# 3      Amateur       True  23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4f...
# 4      Regular       True  7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb...
# ..         ...        ...                                                ...
# 191    Amateur       True  b6e9e593b9ec51c5e335457341c324c34a2239531e1890...
# 192    Veteran      False  71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778...
# 193    Amateur      False  d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db29...
# 194    Amateur      False  f19e136ddde68f365afc860c725ccff54307dedd13968e...
# 195        Pro       True  d9473710057f7d42f36570f0be83817a4eea614029ff90...
#
# ...

# %%
players_filter = players[['experience', 'played_hours']]


grouped = players_filter.groupby('experience').mean().reset_index()


bar_plot = alt.Chart(grouped).mark_bar().encode(
    x=alt.X('experience').title('Experience'),
    y=alt.Y('played_hours').title('Average Played Hours')
)
    


bar_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# This plot shows that players with a regular experience seems to produce on averageage the most amount of hours played and veteran seems to be the least hours played

# %% [markdown]
# 4)  I will split the data into 80% Training set and 20% testing set to en sure that the future predictions are correct
